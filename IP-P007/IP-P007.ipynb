# %% [markdown]
# # Exercício 1: Carregando e analisando um DataSet
#
# ## Dados Estação Cuiabá 2003

# %%
import pandas as pd

# Carrega o arquivo csv

dataframe2003 = pd.read_csv('./datasets/INMET_CO_MT_A901_CUIABA_01-01-2003_A_31-12-2003.CSV', sep=';', encoding='ISO-8859-1')

# Exibe os primeiros registros do dataframe
dataframe2003.head()
# Out:
#          DATA HORA (UTC) PRECIPITAÇÃO TOTAL, HORÁRIO (MM)  \
# 0  01/01/2003      00:00                            -9999
# 1  01/01/2003      01:00                            -9999
# 2  01/01/2003      02:00                            -9999
# 3  01/01/2003      03:00                            -9999
# 4  01/01/2003      04:00                            -9999
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              -9999
# 1                                              -9999
# 2                                              -9999
# 3                                              -9999
# 4                                              -9999
#
#   PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           -9999
# 1                                           -9999
# 2                                           -9999
# 3                                           -9999
# ...

# %% [markdown]
# ## Dados Estação Cuiabá 2013

# %%
# Carregar o arquivo csv

dataframe2013 = pd.read_csv('./datasets/INMET_CO_MT_A901_CUIABA_01-01-2013_A_31-12-2013.CSV', sep=';', encoding='ISO-8859-1')

# Exibe os primeiros registros do dataframe
dataframe2013.head()
# Out:
#          DATA HORA (UTC) PRECIPITAÇO TOTAL, HORµRIO (mm)  \
# 0  01/01/2013      00:00                              0,4
# 1  01/01/2013      01:00                              1,2
# 2  01/01/2013      02:00                              0,4
# 3  01/01/2013      03:00                                0
# 4  01/01/2013      04:00                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              983,5
# 1                                              983,9
# 2                                              984,4
# 3                                              984,9
# 4                                              984,3
#
#   PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           983,5
# 1                                             984
# 2                                           984,5
# 3                                             985
# ...

# %% [markdown]
# # Dados Estação Cuiabá 2023

# %%
# Carregar o arquivo csv

dataframe2023 = pd.read_csv('./datasets/INMET_CO_MT_A901_CUIABA_01-01-2023_A_31-12-2023.CSV', sep=';', encoding='ISO-8859-1')

# Exibe os primeiros registros do dataframe
dataframe2023.head()
# Out:
#          DATA  Hora UTC PRECIPITAÇO TOTAL, HORµRIO (mm)  \
# 0  01/01/2023  0000 UTC                              NaN
# 1  01/01/2023  0100 UTC                              NaN
# 2  01/01/2023  0200 UTC                              NaN
# 3  01/01/2023  0300 UTC                                0
# 4  01/01/2023  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              990,5
# 4                                              990,2
#
#   PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                           990,5
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.shape
# Out:
# (8768, 19)

# %% [markdown]
# # Exercício 2: Juntando os datasets
# ### 1.0

# %%
import pandas as pd

# Suponha que você tenha três DataFrames chamados dataframe2003, dataframe2013 e dataframe2023
# Substitua os nomes dos DataFrames pelos seus nomes reais

# Leia os arquivos CSV ou substitua pelo método adequado para carregar seus DataFrames
dataframe2003 = pd.read_csv('./datasets/INMET_CO_MT_A901_CUIABA_01-01-2003_A_31-12-2003.CSV', sep=';', encoding='ISO-8859-1', skiprows=7)
dataframe2013 = pd.read_csv('./datasets/INMET_CO_MT_A901_CUIABA_01-01-2013_A_31-12-2013.CSV', sep=';', encoding='ISO-8859-1', skiprows=7)
dataframe2023 = pd.read_csv('./datasets/INMET_CO_MT_A901_CUIABA_01-01-2023_A_31-12-2023.CSV', sep=';', encoding='ISO-8859-1', skiprows=8)

# Concatene os DataFrames ao longo do eixo das linhas
df_concat = pd.concat([dataframe2003, dataframe2013, dataframe2023])

# Visualize o DataFrame com MultiIndex no índice
print(df_concat)
# Out:
#       01/01/2003  06:00  -9999 -9999.1 -9999.2 -9999.3  -9999.4  24,8  23,6  \
# 0     01/01/2003  07:00  -9999   -9999   -9999   -9999  -9999.0  24,8  23,5
# 1     01/01/2003  08:00  -9999   -9999   -9999   -9999  -9999.0  24,5  23,2
# 2     01/01/2003  09:00  -9999   -9999   -9999   -9999  -9999.0  24,6  23,1
# 3     01/01/2003  10:00  -9999   -9999   -9999   -9999  -9999.0    25  23,6
# 4     01/01/2003  11:00  -9999   -9999   -9999   -9999  -9999.0  25,9  23,4
# ...          ...    ...    ...     ...     ...     ...      ...   ...   ...
# 8747         NaN    NaN    NaN     NaN     NaN     NaN      NaN   NaN   NaN
# 8748         NaN    NaN    NaN     NaN     NaN     NaN      NaN   NaN   NaN
# 8749         NaN    NaN    NaN     NaN     NaN     NaN      NaN   NaN   NaN
# 8750         NaN    NaN    NaN     NaN     NaN     NaN      NaN   NaN   NaN
# 8751         NaN    NaN    NaN     NaN     NaN     NaN      NaN   NaN   NaN
#
# ...

# %% [markdown]
# # Exercício 2: Juntando os datasets
# ### 2.0

# %%
import pandas as pd

# Suponha que df_concat seja o DataFrame resultante do código anterior

# Cria uma cópia explícita do DataFrame
df_concat_copy = df_concat.copy()

# Reordenar as colunas para ter os parâmetros agrupados
ordem_colunas = ['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 
                 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
                 'RADIACAO GLOBAL (KJ/m²)',
                 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
                 'UMIDADE RELATIVA DO AR, HORARIA (%)',
                 'VENTO, VELOCIDADE HORARIA (m/s)']

# Selecionar apenas as colunas que estão presentes no DataFrame
colunas_presentes = [coluna for coluna in ordem_colunas if coluna in df_reorganizado.columns.get_level_values(1)]
df_reorganizado = df_reorganizado.loc[:, colunas_presentes]

# Adicionar MultiIndex nas colunas
df_reorganizado.columns = pd.MultiIndex.from_product([['Mes', 'Dia'], df_reorganizado.columns.get_level_values(1)])

# Visualizar o DataFrame reorganizado com MultiIndex nas colunas
print(df_reorganizado)
# Out:
# Empty DataFrame
# Columns: []
# ...
